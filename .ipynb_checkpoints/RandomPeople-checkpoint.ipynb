# %%
import numpy as np
import pandas as pd
import matplotlib
from collections import defaultdict
from matplotlib import pyplot as plt
from urllib import urlencode

import urllib2
import time
import json
import operator
import random

# %%
file = open('datasets/token', 'r')
accessToken = file.read()

# %% [markdown]
# # Случайные люди

# %%
people = []

while len(people) < 2500:
    random_ids = []
    for i in range(0, 100):
        random_ids.append(random.randint(1, 90000000))

    user_ids = ",".join(str(x) for x in random_ids)
    params = {"user_ids": user_ids, 
              "fields": "sex,education,universities,schools,city", 
              "access_token": accessToken}
    params = urlencode(params)

    url = "https://api.vk.com/method/users.get?" + params
    data = json.load(urllib2.urlopen(url))
   
    fetched_people = data.get('response', [])
    fetched_people = filter(lambda x: x.get('deactivated', '') == '', fetched_people)
    fetched_people = filter(lambda x: x.get('city', 0) == 2, fetched_people)
    
    print("extracted %d users" % len(fetched_people))
    people.extend(fetched_people)
    time.sleep(0.25)
    
f = open('datasets/randomPeople/users.json','w')
f.write(json.dumps(people))
f.close()
# Out:
# extracted 5 users
# extracted 4 users
# extracted 1 users
# extracted 11 users
# extracted 4 users
# extracted 4 users
# extracted 4 users
# extracted 2 users
# extracted 3 users
# extracted 2 users
# extracted 3 users
# extracted 6 users
# extracted 3 users
# extracted 3 users
# extracted 4 users
# extracted 5 users
# extracted 4 users
# extracted 2 users
# extracted 3 users
# extracted 4 users
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-2597d64bb1b6> in <module>()
#      13
#      14     url = "https://api.vk.com/method/users.get?" + params
# ---> 15     data = json.load(urllib2.urlopen(url))
#      16
#      17     fetched_people = data.get('response', [])
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1238         def https_open(self, req):
#    1239             return self.do_open(httplib.HTTPSConnection, req,
# -> 1240                 context=self._context)
#    1241
#    1242         https_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1192
#    1193         try:
# -> 1194             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1195         except socket.error, err: # XXX what error?
#    1196             h.close()
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1055     def request(self, method, url, body=None, headers={}):
#    1056         """Send a complete request to the server."""
# -> 1057         self._send_request(method, url, body, headers)
#    1058
#    1059     def _set_content_length(self, body, method):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1095         for hdr, value in headers.iteritems():
#    1096             self.putheader(hdr, value)
# -> 1097         self.endheaders(body)
#    1098
#    1099     def getresponse(self, buffering=False):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1051         else:
#    1052             raise CannotSendHeader()
# -> 1053         self._send_output(message_body)
#    1054
#    1055     def request(self, method, url, body=None, headers={}):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     895             msg += message_body
#     896             message_body = None
# --> 897         self.send(msg)
#     898         if message_body is not None:
#     899             #message_body was not a string (i.e. it is a file) and
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in send(self, data)
#     857         if self.sock is None:
#     858             if self.auto_open:
# --> 859                 self.connect()
#     860             else:
#     861                 raise NotConnected()
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in connect(self)
#    1276
#    1277             self.sock = self._context.wrap_socket(self.sock,
# -> 1278                                                   server_hostname=server_hostname)
#    1279
#    1280     __all__.append("HTTPSConnection")
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     350                          suppress_ragged_eofs=suppress_ragged_eofs,
#     351                          server_hostname=server_hostname,
# --> 352                          _context=self)
#     353
#     354     def set_npn_protocols(self, npn_protocols):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context)
#     577                         # non-blocking
#     578                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 579                     self.do_handshake()
#     580
#     581             except (OSError, ValueError):
#
# /usr/local/Cellar/python/2.7.11/Frameworks/Python.framework/Versions/2.7/lib/python2.7/ssl.pyc in do_handshake(self, block)
#     806             if timeout == 0.0 and block:
#     807                 self.settimeout(None)
# --> 808             self._sslobj.do_handshake()
#     809         finally:
#     810             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
people
# Out:
# [{u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 51940790},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 24118916},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 15482656},
#  {u'first_name': u'Anna',
#   u'last_name': u'Pestova',
#   u'sex': 1,
#   u'uid': 17506849},
#  {u'first_name': u'Vika',
#   u'last_name': u'Almetova',
#   u'sex': 1,
#   u'uid': 58487499},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 19969840},
#  {u'faculty': 15785,
#   u'faculty_name': u'\u0418\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u043e\u043d\u043d\u044b\u0445 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439 \u0438 \u0443\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u044f',
#   u'first_name': u'Pavel',
#   u'graduation': 2009,
#   u'last_name': u'Prudnikov',
#   u'schools': [{u'city': 538,
#     u'class': u'\u044d',
#     u'country': 3,
#     u'id': u'1885',
#     u'name': u'\u041b\u0438\u0446\u0435\u0439 \u21161',
#     u'speciality': u'\u044d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u043e-\u043c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439',
#     u'type': 2,
#     u'type_str': u'Lyceum',
#     u'year_from': 2002,
#     u'year_graduated': 2004,
#     u'year_to': 2004},
#    {u'city': 538,
#     u'class': u'\u0430',
#     u'country': 3,
#     u'id': u'32922',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u211614',
#     u'year_from': 1997,
#     u'year_graduated': 2004,
#     u'year_to': 2002}],
#   u'sex': 2,
#   u'uid': 4067930,
#   u'universities': [{u'chair': 12285,
#     u'chair_name': u'\u0421\u0438\u0441\u0442\u0435\u043c \u0443\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u044f',
#     u'city': 282,
#     u'country': 3,
#     u'education_form': u'Full-time',
#     u'faculty': 15785,
#     u'faculty_name': u'\u0418\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u043e\u043d\u043d\u044b\u0445 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439 \u0438 \u0443\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u044f',
#     u'graduation': 2009,
#     u'id': 94448,
#     u'name': u'\u0411\u0413\u0423\u0418\u0420 (\u0431\u044b\u0432\u0448. \u041c\u0420\u0422\u0418)'}],
#   u'university': 94448,
#   u'university_name': u'\u0411\u0413\u0423\u0418\u0420 (\u0431\u044b\u0432\u0448. \u041c\u0420\u0422\u0418)'},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 14326534},
#  {u'first_name': u'Anyuta',
#   u'last_name': u'Pozitivchigg...',
#   u'sex': 1,
#   u'uid': 80114570},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 43827099},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 13149768},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Sergey',
#   u'graduation': 0,
#   u'last_name': u'Ergus',
#   u'schools': [{u'city': 1112,
#     u'class': u'\u0430',
#     u'country': 1,
#     u'id': u'50422',
#     u'name': u'\u2116 7',
#     u'year_to': 1976}],
#   u'sex': 2,
#   u'uid': 59813372,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Koberckuy',
#   u'graduation': 0,
#   u'last_name': u'Andriy',
#   u'schools': [{u'city': 314,
#     u'class': u'\u0430',
#     u'country': 2,
#     u'id': u'13723',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u2116112 \u0438\u043c. \u0422. \u0428\u0435\u0432\u0447\u0435\u043d\u043a\u043e',
#     u'year_from': 2010,
#     u'year_graduated': 2017,
#     u'year_to': 2017}],
#   u'sex': 2,
#   u'uid': 57746062,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'banned',
#   u'first_name': u'Ilya',
#   u'last_name': u'Kulikov',
#   u'sex': 2,
#   u'uid': 8804965},
#  {u'first_name': u'Irina',
#   u'last_name': u'Merkulova',
#   u'sex': 1,
#   u'uid': 28428828},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Tratata',
#   u'graduation': 0,
#   u'last_name': u'Okuotauts',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 66385362,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'faculty': 936960,
#   u'faculty_name': u'H\xf6nnun og arkitekt\xfar',
#   u'first_name': u'boel.is@hotmail.com',
#   u'graduation': 1996,
#   u'last_name': u'j\xf3nsd\xf3ttir',
#   u'schools': [{u'city': 2182,
#     u'class': u'',
#     u'country': 86,
#     u'id': u'862588',
#     u'name': u'H\xf3labrekkusk\xf3li',
#     u'year_from': 1996,
#     u'year_graduated': 1996,
#     u'year_to': 1996}],
#   u'sex': 2,
#   u'uid': 56806195,
#   u'universities': [{u'city': 2182,
#     u'country': 86,
#     u'education_form': u'Full-time',
#     u'education_status': u'Student (Specialist)',
#     u'faculty': 936960,
#     u'faculty_name': u'H\xf6nnun og arkitekt\xfar',
#     u'graduation': 1996,
#     u'id': 528083,
#     u'name': u'Listah\xe1sk\xf3li \xcdslands'}],
#   u'university': 528083,
#   u'university_name': u'Listah\xe1sk\xf3li \xcdslands'},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 27501713},
#  {u'first_name': u'Vladimir',
#   u'last_name': u'Soveysky',
#   u'sex': 2,
#   u'uid': 66445247},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Tanyusha',
#   u'graduation': 0,
#   u'last_name': u'Tsunyak',
#   u'schools': [{u'city': 438,
#     u'class': u'\u0431',
#     u'country': 2,
#     u'id': u'1780',
#     u'name': u'\u2116 11',
#     u'year_from': 2004}],
#   u'sex': 1,
#   u'uid': 84549918,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'banned',
#   u'first_name': u'Vitaly',
#   u'last_name': u'Yakoltsevich',
#   u'sex': 2,
#   u'uid': 84442519},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 42983861},
#  {u'first_name': u'Nikolay',
#   u'last_name': u'Morozov',
#   u'sex': 2,
#   u'uid': 62802292},
#  {u'deactivated': u'banned',
#   u'first_name': u'Denis',
#   u'last_name': u'Molodoy Barin',
#   u'sex': 2,
#   u'uid': 54668008},
#  {u'faculty': 35222,
#   u'faculty_name': u'\u041f\u0441\u0438\u0445\u043e\u043b\u043e\u0433\u0438\u0438',
#   u'first_name': u'Natasha',
#   u'graduation': 2011,
#   u'last_name': u'Pavlenko',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 15996990,
#   u'universities': [{u'chair': 40676,
#     u'chair_name': u'\u041f\u0435\u0434\u0430\u0433\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0439 \u043f\u0441\u0438\u0445\u043e\u043b\u043e\u0433\u0438\u0438 \u0438 \u0430\u043d\u0433\u043b\u0438\u0439\u0441\u043a\u043e\u0433\u043e \u044f\u0437\u044b\u043a\u0430',
#     u'city': 650,
#     u'country': 2,
#     u'education_form': u'Full-time',
#     u'education_status': u'Student (Specialist)',
#     u'faculty': 35222,
#     u'faculty_name': u'\u041f\u0441\u0438\u0445\u043e\u043b\u043e\u0433\u0438\u0438',
#     u'graduation': 2011,
#     u'id': 16620,
#     u'name': u'\u0414\u041d\u0423'}],
#   u'university': 16620,
#   u'university_name': u'\u0414\u041d\u0423 \u0438\u043c. \u041e\u043b\u0435\u0441\u044f \u0413\u043e\u043d\u0447\u0430\u0440\u0430'},
#  {u'first_name': u'Vlad',
#   u'last_name': u'Zarudny',
#   u'sex': 2,
#   u'uid': 27578905},
#  {u'faculty': 38696,
#   u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u0430 (\u0431\u044b\u0432\u0448. \u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u043d\u044b\u0439)',
#   u'first_name': u'Alina',
#   u'graduation': 2017,
#   u'last_name': u'Pestova',
#   u'schools': [{u'city': 360,
#     u'class': u'\u0432',
#     u'country': 1,
#     u'id': u'988',
#     u'name': u'\u2116 2',
#     u'year_from': 1999,
#     u'year_graduated': 2008,
#     u'year_to': 2008},
#    {u'city': 135,
#     u'class': u'\u0441',
#     u'country': 1,
#     u'id': u'245515',
#     u'name': u'\u041a\u043e\u043b\u043b\u0435\u0434\u0436 \u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u0430, \u044d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u0438 \u043f\u0440\u0430\u0432\u0430 (\u0421\u041a\u0421\u042d\u0438\u041f)',
#     u'type': 8,
#     u'type_str': u'College',
#     u'year_from': 2008,
#     u'year_graduated': 2013,
#     u'year_to': 2013}],
#   u'sex': 1,
#   u'uid': 84863683,
#   u'universities': [{u'city': 360,
#     u'country': 1,
#     u'education_status': u"Student (Bachelor's)",
#     u'faculty': 38696,
#     u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432\u0430 (\u0431\u044b\u0432\u0448. \u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u043d\u044b\u0439)',
#     u'graduation': 2017,
#     u'id': 523,
#     u'name': u'\u041a\u0413\u0410\u0421\u0423\r\n'}],
#   u'university': 523,
#   u'university_name': u'\u041a\u0413\u0410\u0421\u0423\r\n'},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Agasi',
#   u'graduation': 0,
#   u'last_name': u'Esayan',
#   u'schools': [{u'city': 67,
#     u'class': u'\u0431',
#     u'country': 0,
#     u'id': u'12018',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u21168',
#     u'year_from': 1987,
#     u'year_graduated': 1997,
#     u'year_to': 1997}],
#   u'sex': 2,
#   u'uid': 29458056,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 36821617},
#  {u'first_name': u'Sama', u'last_name': u'Sob', u'sex': 2, u'uid': 57395398},
#  {u'first_name': u'Polina',
#   u'last_name': u'Lebedeva',
#   u'sex': 1,
#   u'uid': 54846371},
#  {u'first_name': u'Ksana',
#   u'last_name': u'Verbova',
#   u'sex': 1,
#   u'uid': 1494943},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 42973135},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 54173344},
#  {u'first_name': u'Alexey',
#   u'last_name': u'Mishin',
#   u'sex': 2,
#   u'uid': 76229021},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Lyokha',
#   u'graduation': 0,
#   u'last_name': u'Kiryushin',
#   u'schools': [{u'city': 1,
#     u'class': u'\u0430',
#     u'country': 0,
#     u'id': u'9398',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u21161162',
#     u'year_from': 1996,
#     u'year_graduated': 2005,
#     u'year_to': 2005}],
#   u'sex': 2,
#   u'uid': 23288593,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'first_name': u'Mila',
#   u'last_name': u'Aprelskaya',
#   u'sex': 2,
#   u'uid': 10544472},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 38108087},
#  {u'faculty': 85561,
#   u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u043c\u0430\u0448\u0438\u043d\u043e\u0441\u0442\u0440\u043e\u0435\u043d\u0438\u044f ',
#   u'first_name': u'Natalya',
#   u'graduation': 1996,
#   u'last_name': u'Serebrennikova',
#   u'schools': [{u'city': 143,
#     u'class': u'\u0431',
#     u'country': 1,
#     u'id': u'138575',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u211660',
#     u'year_from': 1984,
#     u'year_graduated': 1991,
#     u'year_to': 1991}],
#   u'sex': 1,
#   u'uid': 44712785,
#   u'universities': [{u'chair': 1812644,
#     u'chair_name': u'\u041a\u043e\u043c\u043f\u044c\u044e\u0442\u0435\u0440\u043d\u044b\u0435 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0438 \u0438 \u043e\u0431\u0440\u0430\u0431\u043e\u0442\u043a\u0430 \u043c\u0430\u0442\u0435\u0440\u0438\u0430\u043b\u043e\u0432 \u0434\u0430\u0432\u043b\u0435\u043d\u0438\u0435\u043c',
#     u'city': 143,
#     u'country': 1,
#     u'education_form': u'Full-time',
#     u'education_status': u'Alumna (Specialist)',
#     u'faculty': 85561,
#     u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u043c\u0430\u0448\u0438\u043d\u043e\u0441\u0442\u0440\u043e\u0435\u043d\u0438\u044f ',
#     u'graduation': 1996,
#     u'id': 846,
#     u'name': u'\u0422\u0413\u0423 (\u0431\u044b\u0432\u0448. \u0422\u043e\u043b\u041f\u0418, \u0444\u0438\u043b\u0438\u0430\u043b \u0421\u0413\u041f\u0423)'}],
#   u'university': 846,
#   u'university_name': u'\u0422\u0413\u0423 (\u0431\u044b\u0432\u0448. \u0422\u043e\u043b\u041f\u0418, \u0444\u0438\u043b\u0438\u0430\u043b \u0421\u0413\u041f\u0423)'},
#  {u'faculty': 197172,
#   u'faculty_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u0438 \u043c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#   u'first_name': u'Valera',
#   u'graduation': 2009,
#   u'last_name': u'Mardar',
#   u'schools': [{u'city': 1710959,
#     u'class': u'\u0430',
#     u'country': 15,
#     u'id': u'96405',
#     u'name': u'Liceul Teoretic A. Russo (\u0422\u0435\u043e\u0440\u0435\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u043b\u0438\u0446\u0435\u0439 \u0438\u043c. \u0420\u0443\u0441\u0441\u043e, \u015ecoala \u211653)',
#     u'speciality': u'\u041c\u0430\u0442\u0435\u043c\u0430\u0442\u0438\u043a\u0430 :)',
#     u'type': 2,
#     u'type_str': u'Lyceum',
#     u'year_from': 1998,
#     u'year_graduated': 2006,
#     u'year_to': 2006}],
#   u'sex': 2,
#   u'uid': 23519852,
#   u'universities': [{u'chair': 157218,
#     u'chair_name': u'\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u043e\u0433\u043e \u043c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#     u'city': 1710959,
#     u'country': 15,
#     u'education_form': u'Full-time',
#     u'education_status': u"Student (Bachelor's)",
#     u'faculty': 197172,
#     u'faculty_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u0438 \u043c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#     u'graduation': 2009,
#     u'id': 18403,
#     u'name': u'IMI Nova'}],
#   u'university': 18403,
#   u'university_name': u'IMI Nova'},
#  {u'faculty': 34211,
#   u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u044d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 (\u0431\u044b\u0432\u0448. \u042d\u043a\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u0438\u0439)',
#   u'first_name': u'Alim',
#   u'graduation': 2004,
#   u'last_name': u'Tleuzhev',
#   u'schools': [],
#   u'sex': 2,
#   u'uid': 24160140,
#   u'universities': [{u'chair': 194904,
#     u'chair_name': u'\u0411\u0443\u0445\u0433\u0430\u043b\u0442\u0435\u0440\u0441\u043a\u043e\u0433\u043e \u0443\u0447\u0435\u0442\u0430 \u0438 \u0430\u0443\u0434\u0438\u0442\u0430',
#     u'city': 90,
#     u'country': 1,
#     u'education_form': u'Full-time',
#     u'education_status': u'Alumnus (Specialist)',
#     u'faculty': 34211,
#     u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u044d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 (\u0431\u044b\u0432\u0448. \u042d\u043a\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u0438\u0439)',
#     u'graduation': 2004,
#     u'id': 636,
#     u'name': u'\u041a\u0411\u0413\u0421\u0425\u0410 \u0438\u043c. \u041a\u043e\u043a\u043e\u0432\u0430'}],
#   u'university': 636,
#   u'university_name': u'\u041a\u0411\u0413\u0410\u0423 (\u0431\u044b\u0432\u0448. \u041a\u0411\u0413\u0421\u0425\u0410) \u0438\u043c. \u041a\u043e\u043a\u043e\u0432\u0430'},
#  {u'faculty': 26197,
#   u'faculty_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u0438 \u043c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#   u'first_name': u'Lena',
#   u'graduation': 2011,
#   u'last_name': u'Myakina',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 21766887,
#   u'universities': [{u'chair': 41062,
#     u'chair_name': u'\u041c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#     u'city': 650,
#     u'country': 2,
#     u'education_form': u'Full-time',
#     u'education_status': u"Student (Bachelor's)",
#     u'faculty': 26197,
#     u'faculty_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u0438 \u043c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#     u'graduation': 2011,
#     u'id': 3244,
#     u'name': u'\u041d\u041c\u0435\u0442\u0410\u0423'}],
#   u'university': 3244,
#   u'university_name': u'\u041d\u041c\u0435\u0442\u0410\u0423'},
#  {u'deactivated': u'banned',
#   u'first_name': u'IZVINI',
#   u'last_name': u'ZA VSYo',
#   u'sex': 2,
#   u'uid': 53196195},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Natalya',
#   u'graduation': 0,
#   u'last_name': u'Evazova',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 16316366,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 48615771},
#  {u'faculty': 29152,
#   u'faculty_name': u'\u042e\u0440\u0438\u0434\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0438\u043d\u0441\u0442\u0438\u0442\u0443\u0442',
#   u'first_name': u'Manuk',
#   u'graduation': 2014,
#   u'last_name': u'Manukyan',
#   u'schools': [{u'city': 102,
#     u'class': u'\u0431',
#     u'country': 1,
#     u'id': u'3106',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u211629',
#     u'year_from': 1997,
#     u'year_graduated': 2007,
#     u'year_to': 2007}],
#   u'sex': 2,
#   u'uid': 13037684,
#   u'universities': [{u'chair': 1842111,
#     u'chair_name': u'\u0423\u0433\u043e\u043b\u043e\u0432\u043d\u043e\u0433\u043e \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u0430, \u043a\u0440\u0438\u043c\u0438\u043d\u0430\u043b\u0438\u0441\u0442\u0438\u043a\u0438 \u0438 \u043f\u0440\u0430\u0432\u043e\u0432\u043e\u0439 \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0442\u0438\u043a\u0438',
#     u'city': 61,
#     u'country': 1,
#     u'education_form': u'Distance Learning',
#     u'education_status': u'Student (Specialist)',
#     u'faculty': 29152,
#     u'faculty_name': u'\u042e\u0440\u0438\u0434\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0438\u043d\u0441\u0442\u0438\u0442\u0443\u0442',
#     u'graduation': 2014,
#     u'id': 541,
#     u'name': u'\u0411\u0424\u0423 \u0438\u043c. \u041a\u0430\u043d\u0442\u0430 (\u0431\u044b\u0432\u0448. \u0420\u0413\u0423 \u0438\u043c. \u041a\u0430\u043d\u0442\u0430)'}],
#   u'university': 541,
#   u'university_name': u'\u0411\u0424\u0423 \u0438\u043c. \u041a\u0430\u043d\u0442\u0430 (\u0431\u044b\u0432\u0448. \u0420\u0413\u0423 \u0438\u043c. \u041a\u0430\u043d\u0442\u0430)'},
#  {u'faculty': 797864,
#   u'faculty_name': u'\u041c\u0430\u0448\u0438\u043d \u0438 \u043e\u0431\u043e\u0440\u0443\u0434\u043e\u0432\u0430\u043d\u0438\u044f \u0430\u0433\u0440\u043e\u043f\u0440\u043e\u043c\u044b\u0448\u043b\u0435\u043d\u043d\u043e\u0433\u043e \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441\u0430',
#   u'first_name': u'Sergey',
#   u'graduation': 2011,
#   u'last_name': u'Merzlikin',
#   u'schools': [{u'city': 2322,
#     u'class': u'\u0430',
#     u'country': 1,
#     u'id': u'363258',
#     u'name': u'\u2116 4',
#     u'year_from': 1995,
#     u'year_graduated': 2005,
#     u'year_to': 2005}],
#   u'sex': 2,
#   u'uid': 4733679,
#   u'universities': [{u'chair': 648588,
#     u'chair_name': u'\u041c\u0430\u0448\u0438\u043d\u044b \u0438 \u0430\u043f\u043f\u0430\u0440\u0430\u0442\u044b \u043f\u0438\u0449\u0435\u0432\u044b\u0445 \u043f\u0440\u043e\u0438\u0437\u0432\u043e\u0434\u0441\u0442\u0432',
#     u'city': 2322,
#     u'country': 1,
#     u'education_form': u'Full-time',
#     u'education_status': u"Student (Master's)",
#     u'faculty': 797864,
#     u'faculty_name': u'\u041c\u0430\u0448\u0438\u043d \u0438 \u043e\u0431\u043e\u0440\u0443\u0434\u043e\u0432\u0430\u043d\u0438\u044f \u0430\u0433\u0440\u043e\u043f\u0440\u043e\u043c\u044b\u0448\u043b\u0435\u043d\u043d\u043e\u0433\u043e \u043a\u043e\u043c\u043f\u043b\u0435\u043a\u0441\u0430',
#     u'graduation': 2011,
#     u'id': 749,
#     u'name': u'\u0414\u0413\u0422\u0423 (\u0431\u044b\u0432\u0448. \u0420\u0418\u0421\u0425\u041c)'}],
#   u'university': 749,
#   u'university_name': u'\u0414\u0413\u0422\u0423 (\u0431\u044b\u0432\u0448. \u0420\u0418\u0421\u0425\u041c)'},
#  {u'deactivated': u'banned',
#   u'first_name': u'Galya',
#   u'last_name': u'Alikhanova',
#   u'sex': 1,
#   u'uid': 35101158},
#  {u'first_name': u'Pavel',
#   u'last_name': u'Zhemchugov',
#   u'sex': 2,
#   u'uid': 50051014},
#  {u'faculty': 6117,
#   u'faculty_name': u'\u041a\u0443\u043b\u044c\u0442\u0443\u0440\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439',
#   u'first_name': u'Seregey',
#   u'graduation': 2016,
#   u'last_name': u'Kalugi',
#   u'schools': [{u'city': 158,
#     u'class': u'\u0432',
#     u'country': 1,
#     u'id': u'27387',
#     u'name': u'\u2116 46',
#     u'year_from': 2005,
#     u'year_graduated': 2017,
#     u'year_to': 2017}],
#   u'sex': 2,
#   u'uid': 79449431,
#   u'universities': [{u'chair': 42526,
#     u'chair_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u0438 \u0443\u043f\u0440\u0430\u0432\u043b\u0435\u043d\u0438\u044f \u043d\u0430 \u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0438 (\u0443\u0447\u0440\u0435\u0436\u0434\u0435\u043d\u0438\u044f \u043a\u0443\u043b\u044c\u0442\u0443\u0440\u044b \u0438 \u0438\u0441\u043a\u0443\u0441\u0441\u0442\u0432\u0430',
#     u'city': 158,
#     u'country': 1,
#     u'education_form': u'Distance Learning',
#     u'education_status': u'Student (Specialist)',
#     u'faculty': 6117,
#     u'faculty_name': u'\u041a\u0443\u043b\u044c\u0442\u0443\u0440\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u0438\u0439',
#     u'graduation': 2016,
#     u'id': 911,
#     u'name': u'\u0427\u0413\u0410\u041a\u0418\r\n'}],
#   u'university': 911,
#   u'university_name': u'\u0427\u0413\u0418\u041a (\u0431\u044b\u0432\u0448. \u0427\u0413\u0410\u041a\u0418)'},
#  {u'faculty': 154,
#   u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u0430\u0433\u0440\u043e\u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439, \u043f\u043e\u0447\u0432\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u044f \u0438 \u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0438 (\u0431\u044b\u0432\u0448. \u041f\u043e\u0447\u0432\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u044f \u0438 \u0430\u0433\u0440\u043e\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0438, \u0410\u0433\u0440\u043e\u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439 \u0438 \u0434\u0435\u043a\u043e\u0440\u0430\u0442\u0438\u0432\u043d\u043e\u0433\u043e \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0435\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u041f\u043b\u043e\u0434\u043e\u043e\u0432\u043e\u0449\u0435\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u0417\u0430\u0449\u0438\u0442\u044b \u0438 \u043a\u0430\u0440\u0430\u043d\u0442\u0438\u043d\u0430 \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0439, \u0410\u0433\u0440\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u0438\u0439)',
#   u'first_name': u'Elena',
#   u'graduation': 1997,
#   u'last_name': u'Bologova',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 86029176,
#   u'universities': [{u'chair': 1705511,
#     u'chair_name': u'\u0411\u0438\u043e\u043b\u043e\u0433\u0438\u0447\u0435\u0441\u043a\u043e\u0439 \u0437\u0430\u0449\u0438\u0442\u044b \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0439',
#     u'city': 2,
#     u'country': 1,
#     u'education_form': u'Distance Learning',
#     u'faculty': 154,
#     u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u0430\u0433\u0440\u043e\u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439, \u043f\u043e\u0447\u0432\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u044f \u0438 \u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0438 (\u0431\u044b\u0432\u0448. \u041f\u043e\u0447\u0432\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u044f \u0438 \u0430\u0433\u0440\u043e\u044d\u043a\u043e\u043b\u043e\u0433\u0438\u0438, \u0410\u0433\u0440\u043e\u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439 \u0438 \u0434\u0435\u043a\u043e\u0440\u0430\u0442\u0438\u0432\u043d\u043e\u0433\u043e \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0435\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u041f\u043b\u043e\u0434\u043e\u043e\u0432\u043e\u0449\u0435\u0432\u043e\u0434\u0441\u0442\u0432\u0430, \u0417\u0430\u0449\u0438\u0442\u044b \u0438 \u043a\u0430\u0440\u0430\u043d\u0442\u0438\u043d\u0430 \u0440\u0430\u0441\u0442\u0435\u043d\u0438\u0439, \u0410\u0433\u0440\u043e\u043d\u043e\u043c\u0438\u0447\u0435\u0441\u043a\u0438\u0439)',
#     u'graduation': 1997,
#     u'id': 46,
#     u'name': u'\u0421\u041f\u0431\u0413\u0410\u0423'}],
#   u'university': 46,
#   u'university_name': u'\u0421\u041f\u0431\u0413\u0410\u0423'},
#  {u'deactivated': u'banned',
#   u'first_name': u'Lilia',
#   u'last_name': u'Rud',
#   u'sex': 1,
#   u'uid': 42428293},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 24654116},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Sergey',
#   u'graduation': 0,
#   u'last_name': u'Dulsky',
#   u'schools': [],
#   u'sex': 2,
#   u'uid': 81623158,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 18986658},
#  {u'first_name': u'Svetlana',
#   u'last_name': u'Dryupina',
#   u'sex': 1,
#   u'uid': 83234096},
#  {u'faculty': 11508,
#   u'faculty_name': u'\u041c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#   u'first_name': u'Ekaterina',
#   u'graduation': 2009,
#   u'last_name': u'Sklyarova-Bocharova',
#   u'schools': [{u'city': 4832,
#     u'class': u'\u0430',
#     u'country': 2,
#     u'id': u'57481',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u21164',
#     u'year_from': 1994,
#     u'year_graduated': 2004,
#     u'year_to': 2004}],
#   u'sex': 1,
#   u'uid': 76484453,
#   u'universities': [{u'chair': 90575,
#     u'chair_name': u'\u041c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442 \u0432 \u043f\u0440\u043e\u0438\u0437\u0432\u043e\u0434\u0441\u0442\u0432\u0435\u043d\u043d\u043e\u0439 \u0441\u0444\u0435\u0440\u0435',
#     u'city': 4832,
#     u'country': 2,
#     u'education_form': u'Full-time',
#     u'education_status': u"Alumna (Master's)",
#     u'faculty': 11508,
#     u'faculty_name': u'\u041c\u0435\u043d\u0435\u0434\u0436\u043c\u0435\u043d\u0442\u0430',
#     u'graduation': 2009,
#     u'id': 2602,
#     u'name': u'\u0414\u043e\u043d\u0413\u0423\u0423 (\u0431\u044b\u0432\u0448. \u0410\u0423)'}],
#   u'university': 2602,
#   u'university_name': u'\u0414\u043e\u043d\u0413\u0423\u0423 (\u0431\u044b\u0432\u0448. \u0410\u0423)'},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Shakal',
#   u'graduation': 0,
#   u'last_name': u'Shakalov',
#   u'schools': [{u'city': 1,
#     u'class': u'\u0432',
#     u'country': 1,
#     u'id': u'5230',
#     u'name': u'\u2116 563',
#     u'year_from': 1999,
#     u'year_graduated': 2016,
#     u'year_to': 2016}],
#   u'sex': 2,
#   u'uid': 82184539,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'banned',
#   u'first_name': u'Rinat',
#   u'last_name': u'Hesenov',
#   u'sex': 2,
#   u'uid': 23759267},
#  {u'deactivated': u'deleted',
#   u'first_name': u'Alexander',
#   u'last_name': u'Kovtunenko',
#   u'sex': 2,
#   u'uid': 69976006},
#  {u'first_name': u'Nikolay',
#   u'last_name': u'Turyev',
#   u'sex': 2,
#   u'uid': 63525482},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 84959886},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Vitalik',
#   u'graduation': 0,
#   u'last_name': u'Bulychyov',
#   u'schools': [],
#   u'sex': 2,
#   u'uid': 56299130,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Bekzod',
#   u'graduation': 0,
#   u'last_name': u'Fayzullayev',
#   u'schools': [{u'city': 1,
#     u'class': u'\u0430',
#     u'country': 1,
#     u'id': u'21081',
#     u'name': u'\u2116 901',
#     u'speciality': u'123',
#     u'year_from': 2001,
#     u'year_graduated': 2001,
#     u'year_to': 2011}],
#   u'sex': 2,
#   u'uid': 69756062,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'first_name': u'Katerina',
#   u'last_name': u'Ionova',
#   u'sex': 1,
#   u'uid': 82489035},
#  {u'deactivated': u'deleted',
#   u'first_name': u'Azalia',
#   u'last_name': u'Kamalova',
#   u'sex': 1,
#   u'uid': 84776962},
#  {u'first_name': u'Maria',
#   u'last_name': u'Kolodina',
#   u'sex': 1,
#   u'uid': 108229},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Sasha',
#   u'graduation': 0,
#   u'last_name': u'Chernetskaya',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 56198039,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Alexey',
#   u'graduation': 0,
#   u'last_name': u'Zdvizhkov',
#   u'schools': [],
#   u'sex': 2,
#   u'uid': 55433688,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 56989950},
#  {u'deactivated': u'deleted',
#   u'first_name': u'Vladimir',
#   u'last_name': u'Mikhalyov',
#   u'sex': 2,
#   u'uid': 81373006},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 19536371},
#  {u'first_name': u'Anzhella',
#   u'last_name': u'Danilyuk',
#   u'sex': 1,
#   u'uid': 4761196},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Inessik',
#   u'graduation': 0,
#   u'last_name': u'Shamshutdinova',
#   u'schools': [{u'city': 243,
#     u'class': u'\u0432',
#     u'country': 1,
#     u'id': u'322653',
#     u'name': u'\u2116 8',
#     u'year_from': 2000}],
#   u'sex': 1,
#   u'uid': 74136098,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 36208422},
#  {u'first_name': u'Chelovek',
#   u'last_name': u'Pavuk',
#   u'sex': 2,
#   u'uid': 42944785},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Tanya',
#   u'graduation': 0,
#   u'last_name': u'Fedorova',
#   u'schools': [{u'city': 81,
#     u'class': u'\u0432',
#     u'country': 1,
#     u'id': u'135157',
#     u'name': u'\u2116 13',
#     u'type': 1,
#     u'type_str': u'Grammar school',
#     u'year_from': 1965,
#     u'year_graduated': 1975,
#     u'year_to': 1975}],
#   u'sex': 1,
#   u'uid': 55429820,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 31482235},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Dmitry',
#   u'graduation': 0,
#   u'last_name': u'Nazarov',
#   u'schools': [],
#   u'sex': 2,
#   u'uid': 58058993,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 39377430},
#  {u'deactivated': u'banned',
#   u'first_name': u'Don',
#   u'last_name': u'Kazanova',
#   u'sex': 2,
#   u'uid': 49275885},
#  {u'deactivated': u'banned',
#   u'first_name': u'Bijoters',
#   u'last_name': u'Bijoters',
#   u'sex': 2,
#   u'uid': 78725820},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Alexander',
#   u'graduation': 0,
#   u'last_name': u'Lavrenov',
#   u'schools': [{u'city': 7068,
#     u'class': u'',
#     u'country': 1,
#     u'id': u'70637',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u21162',
#     u'year_graduated': 1988}],
#   u'sex': 2,
#   u'uid': 49742765,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'first_name': u'Alexander',
#   u'last_name': u'Denisov',
#   u'sex': 2,
#   u'uid': 36402170},
#  {u'faculty': 49504,
#   u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u043b\u0435\u0441\u043d\u043e\u0433\u043e \u0438 \u0441\u0430\u0434\u043e\u0432\u043e-\u043f\u0430\u0440\u043a\u043e\u0432\u043e\u0433\u043e \u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0430 (\u0431\u044b\u0432\u0448. \u041b\u0435\u0441\u043e\u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439, \u0421\u0430\u0434\u043e\u0432\u043e-\u043f\u0430\u0440\u043a\u043e\u0432\u043e\u0433\u043e \u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0430 \u0438 \u043b\u0430\u043d\u0434\u0448\u0430\u0444\u0442\u043d\u043e\u0439 \u0430\u0440\u0445\u0438\u0442\u0435\u043a\u0442\u0443\u0440\u044b)',
#   u'first_name': u'Artyom',
#   u'graduation': 2004,
#   u'last_name': u'Ischur',
#   u'schools': [{u'city': 314,
#     u'class': u'',
#     u'country': 2,
#     u'id': u'73970',
#     u'name': u'\u2116 275',
#     u'year_graduated': 2000}],
#   u'sex': 2,
#   u'uid': 16345516,
#   u'universities': [{u'city': 314,
#     u'country': 2,
#     u'faculty': 49504,
#     u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u043b\u0435\u0441\u043d\u043e\u0433\u043e \u0438 \u0441\u0430\u0434\u043e\u0432\u043e-\u043f\u0430\u0440\u043a\u043e\u0432\u043e\u0433\u043e \u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0430 (\u0431\u044b\u0432\u0448. \u041b\u0435\u0441\u043e\u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0439, \u0421\u0430\u0434\u043e\u0432\u043e-\u043f\u0430\u0440\u043a\u043e\u0432\u043e\u0433\u043e \u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0430 \u0438 \u043b\u0430\u043d\u0434\u0448\u0430\u0444\u0442\u043d\u043e\u0439 \u0430\u0440\u0445\u0438\u0442\u0435\u043a\u0442\u0443\u0440\u044b)',
#     u'graduation': 2004,
#     u'id': 7020,
#     u'name': u'\u041d\u0410\u0423 (\u0430\u0433\u0440\u0430\u0440\u043d\u044b\u0439)'}],
#   u'university': 7020,
#   u'university_name': u'\u041d\u0423\u0411\u0438\u041f \u0423\u043a\u0440\u0430\u0438\u043d\u044b (\u0431\u044b\u0432\u0448. \u041d\u0410\u0423)'},
#  {u'first_name': u'Svetlana',
#   u'last_name': u'Mauk-Shevchenko',
#   u'sex': 1,
#   u'uid': 15417262},
#  {u'first_name': u'Joe', u'last_name': u'Jonas', u'sex': 2, u'uid': 44277931},
#  {u'first_name': u'Svetlana',
#   u'last_name': u'Evseenkova',
#   u'sex': 1,
#   u'uid': 11724632},
#  {u'deactivated': u'deleted',
#   u'first_name': u'Evgeny',
#   u'last_name': u'Gaevsky',
#   u'sex': 2,
#   u'uid': 52222295},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Vladimir',
#   u'graduation': 0,
#   u'last_name': u'Alexandrov',
#   u'schools': [{u'city': 1932227,
#     u'class': u'\u0434',
#     u'country': 13,
#     u'id': u'659015',
#     u'name': u'Vilniaus Kalvarij\u0173 pagrindin\u0117 mokykla (buv. 20)',
#     u'year_from': 1983,
#     u'year_graduated': 1993,
#     u'year_to': 1993},
#    {u'city': 141,
#     u'class': u'',
#     u'country': 1,
#     u'id': u'415460',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u211642',
#     u'year_from': 1984,
#     u'year_graduated': 1992,
#     u'year_to': 1992}],
#   u'sex': 2,
#   u'uid': 73410272,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'banned',
#   u'first_name': u'Yulyashka',
#   u'last_name': u'Mayorova',
#   u'sex': 1,
#   u'uid': 57215226},
#  {u'deactivated': u'banned',
#   u'first_name': u'Olga',
#   u'last_name': u'Shpilyova',
#   u'sex': 1,
#   u'uid': 25076962},
#  {u'faculty': 39150,
#   u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u043f\u0440\u0430\u0432\u043e\u043e\u0445\u0440\u0430\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0434\u0435\u044f\u0442\u0435\u043b\u044c\u043d\u043e\u0441\u0442\u0438 (\u0431\u044b\u0432\u0448. \u0421\u043b\u0435\u0434\u0441\u0442\u0432\u0435\u043d\u043d\u043e-\u043a\u0440\u0438\u043c\u0438\u043d\u0430\u043b\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439, \u0420\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u043e\u0433\u043e \u0438 \u043c\u0435\u0436\u0434\u0443\u043d\u0430\u0440\u043e\u0434\u043d\u043e\u0433\u043e \u043f\u0440\u0430\u0432\u0430)',
#   u'first_name': u'Sergey',
#   u'graduation': 2007,
#   u'last_name': u'Rybkin',
#   u'schools': [{u'city': 3125,
#     u'class': u'\u0431',
#     u'country': 1,
#     u'id': u'70554',
#     u'name': u'\u0428\u043a\u043e\u043b\u0430 \u21163',
#     u'year_from': 1992,
#     u'year_graduated': 2002,
#     u'year_to': 2002}],
#   u'sex': 2,
#   u'uid': 10328648,
#   u'universities': [{u'chair': 146488,
#     u'chair_name': u'\u042e\u0440\u0438\u0441\u043f\u0440\u0443\u0434\u0435\u043d\u0446\u0438\u0438',
#     u'city': 140,
#     u'country': 1,
#     u'education_form': u'Full-time',
#     u'education_status': u'Alumnus (Specialist)',
#     u'faculty': 39150,
#     u'faculty_name': u'\u0418\u043d\u0441\u0442\u0438\u0442\u0443\u0442 \u043f\u0440\u0430\u0432\u043e\u043e\u0445\u0440\u0430\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u043e\u0439 \u0434\u0435\u044f\u0442\u0435\u043b\u044c\u043d\u043e\u0441\u0442\u0438 (\u0431\u044b\u0432\u0448. \u0421\u043b\u0435\u0434\u0441\u0442\u0432\u0435\u043d\u043d\u043e-\u043a\u0440\u0438\u043c\u0438\u043d\u0430\u043b\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439, \u0420\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u043e\u0433\u043e \u0438 \u043c\u0435\u0436\u0434\u0443\u043d\u0430\u0440\u043e\u0434\u043d\u043e\u0433\u043e \u043f\u0440\u0430\u0432\u0430)',
#     u'graduation': 2007,
#     u'id': 795,
#     u'name': u'\u0421\u0413\u0410\u041f (\u0431\u044b\u0432\u0448. \u0421\u0413\u042e\u0418 \u0438\u043c. \u041a\u0443\u0440\u0441\u043a\u043e\u0433\u043e)'}],
#   u'university': 795,
#   u'university_name': u'\u0421\u0413\u042e\u0410 (\u0431\u044b\u0432\u0448. \u0421\u0413\u0410\u041f, \u0421\u0413\u042e\u0418 \u0438\u043c. \u041a\u0443\u0440\u0441\u043a\u043e\u0433\u043e)'},
#  {u'first_name': u'Marina',
#   u'last_name': u'Yablokova',
#   u'sex': 1,
#   u'uid': 25636542},
#  {u'first_name': u'Nadezhda',
#   u'last_name': u'Guseva',
#   u'sex': 1,
#   u'uid': 88147908},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Lena',
#   u'graduation': 0,
#   u'last_name': u'Lavrova',
#   u'schools': [],
#   u'sex': 1,
#   u'uid': 88152560,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'DELETED',
#   u'last_name': u'',
#   u'sex': 0,
#   u'uid': 39919549},
#  {u'faculty': 8619,
#   u'faculty_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u043c\u043e\u0440\u044f',
#   u'first_name': u'Evgeny',
#   u'graduation': 2007,
#   u'last_name': u'Sagaydakov',
#   u'schools': [{u'city': 377,
#     u'class': u'',
#     u'country': 2,
#     u'id': u'25430',
#     u'name': u'\u041c\u043e\u0440\u0441\u043a\u043e\u0439 \u043b\u0438\u0446\u0435\u0439',
#     u'type': 2,
#     u'type_str': u'Lyceum',
#     u'year_graduated': 2002}],
#   u'sex': 2,
#   u'uid': 5957899,
#   u'universities': [{u'chair': 104069,
#     u'chair_name': u'\u0424\u0438\u043d\u0430\u043d\u0441\u043e\u0432',
#     u'city': 377,
#     u'country': 2,
#     u'education_form': u'Full-time',
#     u'education_status': u'Alumnus (Specialist)',
#     u'faculty': 8619,
#     u'faculty_name': u'\u042d\u043a\u043e\u043d\u043e\u043c\u0438\u043a\u0438 \u043c\u043e\u0440\u044f',
#     u'graduation': 2007,
#     u'id': 3297,
#     u'name': u'\u041d\u0423\u041a (\u0431\u044b\u0432\u0448. \u041d\u041a\u0418) \u0438\u043c. \u041c\u0430\u043a\u0430\u0440\u043e\u0432\u0430'}],
#   u'university': 3297,
#   u'university_name': u'\u041d\u0423\u041a (\u0431\u044b\u0432\u0448. \u041d\u041a\u0418) \u0438\u043c. \u041c\u0430\u043a\u0430\u0440\u043e\u0432\u0430'},
#  {u'faculty': 0,
#   u'faculty_name': u'',
#   u'first_name': u'Travyanika',
#   u'graduation': 0,
#   u'last_name': u'Travka',
#   u'schools': [],
#   u'sex': 2,
#   u'uid': 35975065,
#   u'universities': [],
#   u'university': 0,
#   u'university_name': u''},
#  {u'deactivated': u'deleted',
#   u'first_name': u'Alyonka',
#   u'last_name': u'Simonenko',
#   u'sex': 1,
#   u'uid': 43525911}]
